# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("quatet.csv")

# %%
cols = ['historical_sold', 'itemid', 'liked_count',
       'name', 'price', 'price_max', 'price_min', 'shop_location', 'shopid',
       'sold', 'stock', 'view_count']
df =df[cols]
df.sort_values(by = "price",ascending= False)
# Out:
#       historical_sold       itemid  liked_count  \
# 5874                0  14526236059            0
# 169                 0  12266017092            0
# 2339                0   6978239096            0
# 644                 0  15827004164            0
# 1310                0  10578733844            0
# ...               ...          ...          ...
# 5113                0  15726368393            0
# 3063                0  13362568385            0
# 3071                0  12761439174          206
# 1440                0  15219491602            3
# 3125                0  12863701061            0
#
#                                                    name     price  price_max  \
# 5874  Tranh hoa tứ quý dát vàng trang trí treo tường...  18000000   18000000
# 169                      Hộp Quà Tết Sức Khoẻ PS43-7000   7000000    7000000
# 2339      Set quà Tết_ Yến+ Saffron+ Đông trùng hạ thảo   6050000    6050000
# ...

# %%
df
# Out:
#       historical_sold       itemid  liked_count  \
# 0                1057   6011072518          258
# 1                 424   7967789596         6111
# 2                   0  10580152963            2
# 3                   0  11580417134            1
# 4                   0  13966378890            0
# ...               ...          ...          ...
# 5995                0  14411135490            0
# 5996                0  14422693311            1
# 5997                0  14421258105            0
# 5998                0  14414482226            7
# 5999                0  14413645544            1
#
#                                                    name    price  price_max  \
# 0     [HÀNG SẴN - CHIẾT KHẤU CAO] SET QUÀ, HỘP MỨT T...   359000     359000
# 1     Set Quà Tết Xuân 2022 (Set Nặng Tay, Bao Hàng ...   110000     395000
# 2                               Giỏ quà tết 2022 xin xò   330000     330000
# 3                   Giỏ quà Tết An Nhiên -Đoàn viên 🧧🐯🎁   175000     175000
# ...

# %%
#plt.rcParams["figure.figsize"] = (18,3)
a = df.groupby(['shop_location']).sum()

# %%
#plt.ylabel = "liked_count"
plt.xticks(rotation = 90)
plt.plot(a.index,a["historical_sold"])
plt.ylabel("sold Amount")
plt.xlabel('Location', fontsize=18)
plt.title("Item sell by location")
# Out:
# Text(0.5, 1.0, 'Item sell by location')

# %%
a.sort_values(by="historical_sold")
# Out:
#                    historical_sold          itemid  liked_count       price  \
# shop_location
# Yên Bái                          0     28473897559            0     1398000
# Hà Giang                         0     27767274652            3     1385000
# Quảng Ngãi                       0     32170289948            0     1190000
# Điện Biên                        0     22670725077            1     2150000
# Quảng Trị                        0     15419748011            1      105000
# Hậu Giang                        0     13965893004            0      399000
# Indonesia                        0     18450052893            0      181000
# Hà Nam                           0     51492924276          219     2510294
# Bắc Kạn                          0     13437654545           13     1290000
# Thanh Hóa                        0     45401614256           18      236500
# Bình Định                        0     88135645945            2     3466000
# ...

# %%
#plt.rcParams["figure.figsize"] = (18,3) # set the width and height of the plot
fig, ax = plt.subplots(figsize =(15,6))
plt.xticks(rotation=90)
ax.plot(a.index,a["sold"])
ax.set(title="Item sold by location",xlabel = "Location", ylabel="sold amount")
fig.savefig("sample.png")

# %%
fig, ax = plt.subplots(figsize =(15,6))
plt.xticks(rotation=90)
ax.scatter(a.index,a["sold"])
ax.set(title="Item sold by location",xlabel = "Location", ylabel="sold amount")
#fig.savefig("sample.png")
# Out:
# [Text(0.5, 1.0, 'Item sold by location'),
#  Text(0.5, 0, 'Location'),
#  Text(0, 0.5, 'sold amount')]

# %%
fig, ax = plt.subplots(figsize =(15,4))
plt.xticks(rotation=90)
ax.bar(a.index,a["sold"])
ax.set(title="Item sold by location",xlabel = "Location", ylabel="sold amount")
#fig.savefig("sample.png")
# Out:
# [Text(0.5, 1.0, 'Item sold by location'),
#  Text(0.5, 0, 'Location'),
#  Text(0, 0.5, 'sold amount')]

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols = 2,figsize=(15,10),sharex="all",sharey='all')
ax1.plot(np.array([1,2,3,4,5]),np.array([5,4,3,2,1]))
ax2.bar(np.array([1,2,3,4,5]),np.array([5,4,3,2,1]))
ax3.hist(np.array([1,2,3,4,5]),5)
ax4.scatter(np.array([1,2,3,4,5]),np.array([5,4,3,2,1]))

# %%
df1 = pd.read_csv("car_sales.csv")

# %%
df1["Price"] = df1["Price"].str.replace("[\$\,\.]","").str[:-2].astype(int)
df1
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df1.plot(x="Colour",y= "Price");

# %%
sum = df1.groupby(by = "Colour").sum()
sum
# Out:
#         Odometer (KM)  Doors  Price
# Colour
# Black           11179      5  22000
# Blue           132985     11  21500
# Green           99213      4   4500
# Red             87899      4   5000
# White          454738     16  23450

# %%
b = ['Black', 'Blue', 'Green', 'Red', 'White']
plt.plot(b, sum["Price"])
